# %%
import numpy as np
import cv2 
from PIL import Image
import numpy as np

npy = np.load('/home/data/wyq/ABAW_VA/ABAW2-test/ABAW2-EXP/au_dataset_test/Affwild2_processed/compacted_48/2-30-640x360/frame.npy')
np_0 = npy[0,:,:,:]
img_path = '/home/data/lrd/zgp/abaw/AU_test/cropped_aligned/2-30-640x360/00001.jpg'
# 打开图片文件
img = Image.open(img_path)
# 将PIL图片转换为NumPy数组
img_array = np.array(img)
img_array2 = cv2.imread(img_path)
a=1

# %%
cv2.imwrite('/home/data/zhangzr22/abaw/ABAW6_test/2.png',np_0)
# Out:
# True

# %%
img = Image.fromarray(np_0.astype('uint8'), 'RGB')  # 确保类型正确

# %%
img.save('/home/data/zhangzr22/abaw/ABAW6_test/3.png')
